# %% [markdown]
# # CUSTOMHyS v1.1 - Notebook

# %% [markdown]
# ## Setup local repository

# %% [markdown]
# Clone github repository

# %%
# !git clone https://github.com/jose-tapia/nn-hh-umhs-cec22.git
# Out:
# Cloning into 'nn-hh-umhs-cec22'...
# remote: Enumerating objects: 191, done.
# remote: Counting objects: 100% (171/171), done.
# remote: Compressing objects: 100% (132/132), done.
# remote: Total 191 (delta 53), reused 137 (delta 36), pack-reused 20
# Receiving objects: 100% (191/191), 634.26 MiB | 42.18 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# Checking out files: 100% (97/97), done.

# %% [markdown]
# Change directory to github repository

# %%
# %cd nn-hh-umhs-cec22
# Out:
# /content/nn-hh-umhs-cec22

# %% [markdown]
# ## Create an experiment

# %% [markdown]
# Each experiment has three main components:

# %% [markdown]
# ### Experiment settings

# %% [markdown]
# - `ex_config`: General settings for the experiment:
#   - Name of the experiment (`experiment_name`)
#   - Solver to use (`experiment_type`)
#   - Heuristic collection to use (`heuristic_collection_file`)
#   - If use multi-threading pool to speed-up the experiment (`use_parallel`)
#   - The number of threads to invoke (`parallel_pool_size`)

# %% [markdown]
# ### Hyper-heuristic settings

# %% [markdown]
# - `hh_config`: Configuration for the hyper-heuristic. Here is setting the general variables for the hyper-heuristic model ([general settings](https://github.com/jose-tapia/nn-hh-umhs-cec22/blob/bc9c0806c5e81f13027a969bee6debfb1e6d207d/exconf/demo_default_nn_lstm_mem.json#L10-L19)), and the specifics for the neural network model that power the HH model ([neural network settings](https://github.com/jose-tapia/nn-hh-umhs-cec22/blob/bc9c0806c5e81f13027a969bee6debfb1e6d207d/exconf/demo_default_nn_lstm_mem.json#L20-L37)). In general, the name of the parameter indicates which effect will have in the model, the most important are:
#   - `num_steps`: The maximum cardinality for the metaheuristics generated by the model
#   - `num_replicas`: The number of HH models to invoke (runs of the experiment)
#   - `model_params`: Neural network configuration
#     - `memory_length`: Number of neurons for input layer
#     - `sample_params`: Settings for the sequences that serve to train the neural network
#       - `retrieve_sequences`: `True` if wants to use a list of metaheuristics already generated, otherwise, `false` if wants to generate a new list of metaheuristics
#       - `limit_seqs`: Maximum number of sequences to retreive or generate to train the neural network
#       - `store_sequences`: True if wants to store the list of sequences
#     - `epochs`: Number of epochs to train the model
#     - `model_architecture_layers`: List of layers for the neural network

# %% [markdown]
# ### Benchmark function settings

# %% [markdown]
# - `prob_config`: Settings for the benchmark functions to test with:
#   - `dimensions`: List of integer dimensions to consider
#   - `functions`: List of benchmark functions to consider ([full list](https://github.com/jose-tapia/nn-hh-umhs-cec22/blob/bc9c0806c5e81f13027a969bee6debfb1e6d207d/benchmark_func.py#L31-L45))

# %% [markdown]
# ### Example

# %% [markdown]
# The following JSON content is an example of the experiment configuration that should be stored in the folder `exconf`:

# %% [markdown]
# ```
# {
#   "ex_config": {
#     "experiment_name": "demo_default_nn_lstm_mem",
#     "experiment_type": "neural_network",
#     "heuristic_collection_file": "default.txt",
#     "use_parallel": true,
#     "parallel_pool_size": 10
#   },
#   "hh_config": {
#     "num_steps": 30,
#     "num_agents": 30,
#     "num_iterations": 100,
#     "num_replicas": 10,
#     "stagnation_percentage": 0.50,
#     "verbose": true,
#     "repeat_operators": true,
#     "allow_weight_matrix": true,
#     "trial_overflow": false,
#     "solver": "dynamic_metaheuristic",
#     "tabu_idx": 5,
#     "model_params": {
#       "load_model": false,
#       "save_model": false,
#       "memory_length": 25,
#       "encoder" : "default",
#       "epochs": 5,
#       "model_architecture": "LSTM",
#       "model_architecture_layers": [
#         [20, "sigmoid", "LSTM"]
#       ],
#       "fitness_to_weight": "rank",
#       "sample_params": {
#         "retrieve_sequences": false,
#         "limit_seqs": 10,
#         "store_sequences": false
#       }
#     }
#   },
#   "prob_config": {
#     "dimensions": [
#       2,
#       10
#     ],
#     "functions": [
#       "Sphere",
#       "Step",
#       "ZeroSum"
#     ]
#   }
# }
#
# ```

# %% [markdown]
# ## Run experiment

# %% [markdown]
# There is two ways to run the experiments.
# - The first one only needs to receive as parameter the name of the JSON file in `./exconf/` that contains the experiment configuration
# - The second one receive a text file with a list of JSON file names, notice that it is necessary to specify the relative path to such text file (should receive `exconf/lstm_demo.conf`) if the file is in `exconf` folder)
#
# Please review the following subsections to see a few examples

# %% [markdown]
# ### Execute a single experiment

# %% [markdown]
# From the list of possible experiments, execute the demo that uses a neural network with a few iterations for training

# %%
# !python experiment.py  demo_default_nn_lstm_mem
# Out:
# Streaming output truncated to the last 5000 lines.
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  11, Trial:  14, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  12, Trial:   4, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   2, Trial:   1, SO: genetic_crossover & all       , currPerf: 3.13e+01, candPerf: 3.13e+01 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  30, Trial:   2, SO: spiral_dynamic & all          , currPerf: 5.69e+01, candPerf: 5.69e+01 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  12, Trial:   0, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   3, Trial:   0, SO: genetic_crossover & metr      , currPerf: 3.13e+01, candPerf: 3.13e+01 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  23, Trial:   3, SO: random_search & metr          , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  19, Trial:   2, SO: genetic_crossover & all       , currPerf: 1.06e+02, candPerf: 9.00e+01 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  30, Trial:   3, SO: random_search & gree          , currPerf: 5.69e+01, candPerf: 5.69e+01 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  12, Trial:   5, SO: swarm_dynamic & metr          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  13, Trial:   0, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  30, Trial:   4, SO: swarm_dynamic & metr          , currPerf: 5.69e+01, candPerf: 5.69e+01 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   3, Trial:   1, SO: swarm_dynamic & gree          , currPerf: 3.13e+01, candPerf: 3.13e+01 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  13, Trial:   0, SO: firefly_dynamic & all         , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   3, Trial:   2, SO: genetic_crossover & all       , currPerf: 3.13e+01, candPerf: 3.13e+01 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  23, Trial:   4, SO: gravitational_search & prob   , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  30, Trial:   5, SO: spiral_dynamic & prob         , currPerf: 5.69e+01, candPerf: 5.69e+01 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  20, Trial:   0, SO: gravitational_search & all    , currPerf: 9.00e+01, candPerf: 8.30e+01 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  13, Trial:   1, SO: local_random_walk & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  24, Trial:   0, SO: genetic_mutation & gree       , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  13, Trial:   2, SO: differential_mutation & metr  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  24, Trial:   1, SO: genetic_crossover & prob      , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  30, Trial:   6, SO: genetic_crossover & gree      , currPerf: 5.69e+01, candPerf: 5.69e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  13, Trial:   1, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   3, Trial:   3, SO: genetic_mutation & prob       , currPerf: 3.13e+01, candPerf: 3.13e+01 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   3, Trial:   4, SO: genetic_crossover & metr      , currPerf: 3.13e+01, candPerf: 3.13e+01 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   0, SO: genetic_crossover & prob      , currPerf: 8.30e+01, candPerf: 8.30e+01 which: entered
#
# Best fitness: 56.945497827455675,
# Best position: [ 0.78587593 -1.82260057 -2.04386384  0.12164963 -4.51787058  2.37145481
#  -1.11671761  2.7056478   0.28684982  3.75885919]Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  24, Trial:   2, SO: random_sample & prob          , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
#
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   1, SO: genetic_mutation & prob       , currPerf: 8.30e+01, candPerf: 8.30e+01 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  13, Trial:   2, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  24, Trial:   3, SO: genetic_crossover & all       , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  13, Trial:   3, SO: central_force_dynamic & gree  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  13, Trial:   3, SO: random_flight & prob          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  24, Trial:   4, SO: swarm_dynamic & prob          , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   3, Trial:   5, SO: swarm_dynamic & metr          , currPerf: 3.13e+01, candPerf: 1.16e+01 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   4, Trial:   0, SO: differential_mutation & prob  , currPerf: 1.16e+01, candPerf: 1.16e+01 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   1, Trial:   0, SO: genetic_crossover & metr      , currPerf: 1.65e+04, candPerf: 6.41e+03 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   2, SO: random_search & gree          , currPerf: 8.30e+01, candPerf: 8.30e+01 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  24, Trial:   5, SO: swarm_dynamic & gree          , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   2, Trial:   0, SO: random_search & prob          , currPerf: 6.41e+03, candPerf: 6.41e+03 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  14, Trial:   0, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  13, Trial:   4, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  15, Trial:   0, SO: differential_mutation & all   , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   3, SO: genetic_crossover & prob      , currPerf: 8.30e+01, candPerf: 8.30e+01 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   0, SO: differential_mutation & metr  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   5, Trial:   0, SO: differential_mutation & all   , currPerf: 1.16e+01, candPerf: 0.00e+00 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   1, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   6, Trial:   0, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  24, Trial:   6, SO: genetic_crossover & prob      , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   2, Trial:   1, SO: differential_mutation & all   , currPerf: 6.41e+03, candPerf: 6.41e+03 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   2, Trial:   2, SO: random_search & prob          , currPerf: 6.41e+03, candPerf: 6.41e+03 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  15, Trial:   1, SO: random_sample & metr          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   2, Trial:   3, SO: genetic_crossover & all       , currPerf: 6.41e+03, candPerf: 6.41e+03 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   2, SO: random_flight & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  24, Trial:   7, SO: firefly_dynamic & all         , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   4, SO: firefly_dynamic & gree        , currPerf: 8.30e+01, candPerf: 8.30e+01 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   3, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  15, Trial:   2, SO: random_search & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  24, Trial:   8, SO: genetic_mutation & metr       , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  15, Trial:   3, SO: differential_mutation & gree  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   2, Trial:   4, SO: local_random_walk & gree      , currPerf: 6.41e+03, candPerf: 6.41e+03 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   7, Trial:   0, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   7, Trial:   1, SO: local_random_walk & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   5, SO: differential_mutation & gree  , currPerf: 8.30e+01, candPerf: 8.30e+01 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  24, Trial:   9, SO: genetic_crossover & all       , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   6, SO: differential_mutation & gree  , currPerf: 8.30e+01, candPerf: 8.30e+01 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   2, Trial:   5, SO: genetic_crossover & all       , currPerf: 6.41e+03, candPerf: 6.41e+03 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   4, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   7, SO: genetic_crossover & gree      , currPerf: 8.30e+01, candPerf: 8.30e+01 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  24, Trial:  10, SO: random_sample & prob          , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  15, Trial:   4, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   5, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   7, Trial:   2, SO: swarm_dynamic & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   7, Trial:   3, SO: swarm_dynamic & metr          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  15, Trial:   5, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  15, Trial:   6, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   8, SO: genetic_crossover & prob      , currPerf: 8.30e+01, candPerf: 7.40e+01 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  22, Trial:   0, SO: genetic_crossover & all       , currPerf: 7.40e+01, candPerf: 7.40e+01 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   6, SO: gravitational_search & prob   , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   8, Trial:   0, SO: local_random_walk & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  25, Trial:   0, SO: gravitational_search & all    , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   9, Trial:   0, SO: local_random_walk & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   2, Trial:   6, SO: firefly_dynamic & prob        , currPerf: 6.41e+03, candPerf: 6.41e+03 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   7, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  15, Trial:   7, SO: random_sample & metr          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  15, Trial:   8, SO: swarm_dynamic & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  26, Trial:   0, SO: genetic_crossover & gree      , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  22, Trial:   1, SO: swarm_dynamic & metr          , currPerf: 7.40e+01, candPerf: 7.40e+01 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   2, Trial:   7, SO: genetic_crossover & gree      , currPerf: 6.41e+03, candPerf: 6.41e+03 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  22, Trial:   2, SO: genetic_crossover & all       , currPerf: 7.40e+01, candPerf: 6.20e+01 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   9, Trial:   1, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  26, Trial:   1, SO: genetic_crossover & prob      , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   9, Trial:   2, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   2, Trial:   8, SO: genetic_crossover & gree      , currPerf: 6.41e+03, candPerf: 6.41e+03 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  15, Trial:   9, SO: swarm_dynamic & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  26, Trial:   2, SO: genetic_crossover & gree      , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   8, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  16, Trial:   0, SO: differential_mutation & gree  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   2, Trial:   9, SO: genetic_crossover & all       , currPerf: 6.41e+03, candPerf: 5.95e+03 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  23, Trial:   0, SO: swarm_dynamic & gree          , currPerf: 6.20e+01, candPerf: 6.00e+01 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  24, Trial:   0, SO: genetic_crossover & prob      , currPerf: 6.00e+01, candPerf: 6.00e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   9, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   3, Trial:   0, SO: differential_mutation & metr  , currPerf: 5.95e+03, candPerf: 5.95e+03 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   9, Trial:   3, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  26, Trial:   3, SO: genetic_crossover & gree      , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  26, Trial:   4, SO: genetic_crossover & gree      , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:  10, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  16, Trial:   1, SO: genetic_mutation & gree       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   3, Trial:   1, SO: random_sample & prob          , currPerf: 5.95e+03, candPerf: 5.95e+03 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  17, Trial:   0, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  25, Trial:   0, SO: genetic_crossover & all       , currPerf: 6.00e+01, candPerf: 5.80e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:  11, SO: swarm_dynamic & prob          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  26, Trial:   0, SO: genetic_crossover & prob      , currPerf: 5.80e+01, candPerf: 5.70e+01 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  26, Trial:   5, SO: genetic_mutation & prob       , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  10, Trial:   0, SO: swarm_dynamic & prob          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  26, Trial:   6, SO: genetic_crossover & metr      , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  10, Trial:   1, SO: differential_mutation & prob  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:  12, SO: random_sample & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   3, Trial:   2, SO: genetic_crossover & gree      , currPerf: 5.95e+03, candPerf: 5.21e+03 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   4, Trial:   0, SO: differential_mutation & all   , currPerf: 5.21e+03, candPerf: 3.62e+03 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  17, Trial:   1, SO: spiral_dynamic & all          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  17, Trial:   2, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  11, Trial:   0, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   5, Trial:   0, SO: genetic_crossover & metr      , currPerf: 3.62e+03, candPerf: 2.98e+03 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  27, Trial:   0, SO: gravitational_search & all    , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  11, Trial:   1, SO: differential_mutation & gree  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  27, Trial:   1, SO: local_random_walk & prob      , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   6, Trial:   0, SO: local_random_walk & gree      , currPerf: 2.98e+03, candPerf: 2.98e+03 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:  13, SO: central_force_dynamic & all   , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   7, Trial:   0, SO: random_flight & all           , currPerf: 2.98e+03, candPerf: 2.98e+03 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  15, Trial:   0, SO: swarm_dynamic & prob          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  17, Trial:   3, SO: random_search & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   7, Trial:   1, SO: genetic_crossover & all       , currPerf: 2.98e+03, candPerf: 2.89e+03 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  28, Trial:   0, SO: local_random_walk & prob      , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  27, Trial:   0, SO: firefly_dynamic & all         , currPerf: 5.70e+01, candPerf: 5.70e+01 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  17, Trial:   4, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  17, Trial:   5, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  29, Trial:   0, SO: genetic_crossover & all       , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  28, Trial:   0, SO: genetic_crossover & gree      , currPerf: 5.70e+01, candPerf: 5.70e+01 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  28, Trial:   1, SO: genetic_crossover & metr      , currPerf: 5.70e+01, candPerf: 5.70e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  15, Trial:   1, SO: random_search & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  29, Trial:   0, SO: genetic_crossover & gree      , currPerf: 5.70e+01, candPerf: 5.70e+01 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  11, Trial:   2, SO: swarm_dynamic & metr          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  11, Trial:   3, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  11, Trial:   4, SO: swarm_dynamic & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  15, Trial:   2, SO: differential_mutation & metr  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   0, SO: swarm_dynamic & gree          , currPerf: 2.89e+03, candPerf: 2.89e+03 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  30, Trial:   0, SO: random_sample & gree          , currPerf: 5.70e+01, candPerf: 5.70e+01 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  29, Trial:   1, SO: differential_mutation & prob  , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  30, Trial:   1, SO: genetic_crossover & metr      , currPerf: 5.70e+01, candPerf: 5.40e+01 which: entered    +
#
# Best fitness: 54.0,
# Best position: [ -1.60197879  -1.40549562 -14.77071671   0.95314938 -15.17129432
#    1.52326152  -4.24942875  -0.58804412  12.80519402   6.91279993]
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   1, SO: local_random_walk & gree      , currPerf: 2.89e+03, candPerf: 2.56e+03 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  15, Trial:   3, SO: differential_mutation & metr  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  12, Trial:   0, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  29, Trial:   2, SO: genetic_crossover & all       , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   9, Trial:   0, SO: swarm_dynamic & gree          , currPerf: 2.56e+03, candPerf: 2.56e+03 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  18, Trial:   0, SO: firefly_dynamic & all         , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  15, Trial:   4, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  18, Trial:   1, SO: random_flight & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  15, Trial:   5, SO: random_flight & metr          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  30, Trial:   0, SO: genetic_crossover & prob      , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  30, Trial:   1, SO: random_sample & metr          , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  12, Trial:   1, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  30, Trial:   2, SO: random_sample & prob          , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  12, Trial:   2, SO: differential_mutation & prob  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  15, Trial:   6, SO: firefly_dynamic & all         , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   9, Trial:   1, SO: genetic_crossover & prob      , currPerf: 2.56e+03, candPerf: 1.37e+03 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  18, Trial:   2, SO: swarm_dynamic & metr          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  18, Trial:   3, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:  10, Step:   1, Trial:   0, SO: genetic_crossover & prob      , currPerf: 2.93e+02, candPerf: 1.84e+02 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  16, Trial:   0, SO: swarm_dynamic & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:  10, Step:   2, Trial:   0, SO: random_flight & gree          , currPerf: 1.84e+02, candPerf: 1.84e+02 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  30, Trial:   3, SO: firefly_dynamic & all         , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   0, SO: swarm_dynamic & metr          , currPerf: 1.37e+03, candPerf: 1.37e+03 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  17, Trial:   0, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  17, Trial:   1, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  30, Trial:   4, SO: random_search & prob          , currPerf: 1.87e-04, candPerf: 1.87e-04 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   1, SO: genetic_crossover & gree      , currPerf: 1.37e+03, candPerf: 1.08e+03 which: entered    +
#
# Best fitness: 0.00018729459545650608,
# Best position: [-0.01100785 -0.00813153]
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  12, Trial:   3, SO: random_search & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  17, Trial:   2, SO: random_sample & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  12, Trial:   4, SO: local_random_walk & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  19, Trial:   0, SO: random_search & metr          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  17, Trial:   3, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  19, Trial:   1, SO: swarm_dynamic & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:   1, Trial:   0, SO: genetic_crossover & prob      , currPerf: 8.67e+02, candPerf: 1.90e+02 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:   2, Trial:   0, SO: local_random_walk & all       , currPerf: 1.90e+02, candPerf: 2.65e+01 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  11, Trial:   0, SO: genetic_crossover & metr      , currPerf: 1.08e+03, candPerf: 9.18e+02 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:   3, Trial:   0, SO: random_search & metr          , currPerf: 2.65e+01, candPerf: 2.57e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  17, Trial:   4, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  17, Trial:   5, SO: random_flight & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:   4, Trial:   0, SO: genetic_mutation & gree       , currPerf: 2.57e+01, candPerf: 2.57e+01 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  19, Trial:   2, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  12, Trial:   5, SO: swarm_dynamic & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:  10, Step:   2, Trial:   1, SO: central_force_dynamic & metr  , currPerf: 1.84e+02, candPerf: 1.84e+02 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  17, Trial:   6, SO: random_flight & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:  10, Step:   3, Trial:   0, SO: genetic_crossover & all       , currPerf: 1.84e+02, candPerf: 1.04e+02 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  18, Trial:   0, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  12, Trial:   0, SO: genetic_crossover & gree      , currPerf: 9.18e+02, candPerf: 9.18e+02 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:   4, Trial:   1, SO: genetic_crossover & all       , currPerf: 2.57e+01, candPerf: 2.57e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  18, Trial:   1, SO: random_flight & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  12, Trial:   1, SO: differential_mutation & metr  , currPerf: 9.18e+02, candPerf: 9.18e+02 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  12, Trial:   6, SO: central_force_dynamic & prob  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:  10, Step:   4, Trial:   0, SO: genetic_crossover & metr      , currPerf: 1.04e+02, candPerf: 9.80e+01 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:   5, Trial:   0, SO: genetic_crossover & all       , currPerf: 2.57e+01, candPerf: 2.57e+01 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  19, Trial:   3, SO: gravitational_search & metr   , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  12, Trial:   2, SO: random_flight & metr          , currPerf: 9.18e+02, candPerf: 6.62e+02 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:   5, Trial:   1, SO: local_random_walk & gree      , currPerf: 2.57e+01, candPerf: 2.57e+01 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  13, Trial:   0, SO: random_flight & prob          , currPerf: 6.62e+02, candPerf: 5.57e+02 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:   5, Trial:   2, SO: random_search & gree          , currPerf: 2.57e+01, candPerf: 1.90e+01 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  12, Trial:   7, SO: differential_mutation & prob  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  12, Trial:   8, SO: swarm_dynamic & metr          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:  10, Step:   5, Trial:   0, SO: genetic_crossover & all       , currPerf: 9.80e+01, candPerf: 7.80e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  18, Trial:   2, SO: firefly_dynamic & gree        , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  19, Trial:   4, SO: random_search & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  20, Trial:   0, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   0, SO: genetic_crossover & gree      , currPerf: 5.57e+02, candPerf: 5.57e+02 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  18, Trial:   3, SO: differential_mutation & gree  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   1, SO: genetic_crossover & metr      , currPerf: 5.57e+02, candPerf: 5.57e+02 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:   6, Trial:   0, SO: local_random_walk & metr      , currPerf: 1.90e+01, candPerf: 1.90e+01 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:  10, Step:   6, Trial:   0, SO: genetic_crossover & all       , currPerf: 7.80e+01, candPerf: 7.50e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  18, Trial:   4, SO: differential_mutation & gree  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  21, Trial:   0, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  18, Trial:   5, SO: random_flight & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  13, Trial:   0, SO: random_flight & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  18, Trial:   6, SO: swarm_dynamic & metr          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  18, Trial:   7, SO: random_search & prob          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:  10, Step:   7, Trial:   0, SO: genetic_crossover & gree      , currPerf: 7.50e+01, candPerf: 7.50e+01 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  19, Trial:   0, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  20, Trial:   0, SO: random_sample & prob          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:   6, Trial:   1, SO: genetic_crossover & gree      , currPerf: 1.90e+01, candPerf: 1.84e+01 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  21, Trial:   1, SO: genetic_mutation & gree       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  20, Trial:   1, SO: central_force_dynamic & prob  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  14, Trial:   0, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  20, Trial:   2, SO: central_force_dynamic & metr  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:  10, Step:   7, Trial:   1, SO: genetic_crossover & gree      , currPerf: 7.50e+01, candPerf: 6.30e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  21, Trial:   0, SO: firefly_dynamic & metr        , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:   7, Trial:   0, SO: genetic_crossover & metr      , currPerf: 1.84e+01, candPerf: 1.80e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  21, Trial:   1, SO: random_search & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   0, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  21, Trial:   2, SO: local_random_walk & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   1, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:   0, SO: swarm_dynamic & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  14, Trial:   1, SO: local_random_walk & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  14, Trial:   2, SO: differential_mutation & prob  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:   1, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:  10, Step:   8, Trial:   0, SO: local_random_walk & gree      , currPerf: 6.30e+01, candPerf: 6.20e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:   2, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:   3, SO: random_flight & prob          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   2, SO: firefly_dynamic & all         , currPerf: 5.57e+02, candPerf: 5.57e+02 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:   4, SO: random_search & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  15, Trial:   0, SO: genetic_crossover & all       , currPerf: 5.57e+02, candPerf: 5.57e+02 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:   8, Trial:   0, SO: genetic_crossover & prob      , currPerf: 1.80e+01, candPerf: 1.80e+01 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:   8, Trial:   1, SO: swarm_dynamic & all           , currPerf: 1.80e+01, candPerf: 8.91e-01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:   5, SO: firefly_dynamic & metr        , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   2, SO: local_random_walk & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:   6, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  14, Trial:   3, SO: differential_mutation & prob  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:  10, Step:   9, Trial:   0, SO: genetic_crossover & all       , currPerf: 6.20e+01, candPerf: 4.50e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:   7, SO: central_force_dynamic & prob  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  15, Trial:   1, SO: genetic_crossover & all       , currPerf: 5.57e+02, candPerf: 5.57e+02 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:   8, SO: differential_mutation & metr  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:   9, SO: differential_mutation & all   , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:   9, Trial:   0, SO: differential_mutation & gree  , currPerf: 8.91e-01, candPerf: 5.34e-02 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:  10, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   3, SO: random_flight & metr          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:  11, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:  12, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:  10, Step:  10, Trial:   0, SO: genetic_crossover & metr      , currPerf: 4.50e+01, candPerf: 4.50e+01 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  23, Trial:   0, SO: differential_mutation & gree  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  14, Trial:   4, SO: genetic_mutation & all        , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  23, Trial:   1, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  15, Trial:   2, SO: local_random_walk & metr      , currPerf: 5.57e+02, candPerf: 5.57e+02 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  23, Trial:   2, SO: swarm_dynamic & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  23, Trial:   3, SO: random_flight & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:  10, Trial:   0, SO: random_search & all           , currPerf: 5.34e-02, candPerf: 5.34e-02 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:  10, Trial:   1, SO: random_flight & metr          , currPerf: 5.34e-02, candPerf: 5.34e-02 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  23, Trial:   4, SO: genetic_mutation & prob       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:  10, Step:  10, Trial:   1, SO: differential_mutation & gree  , currPerf: 4.50e+01, candPerf: 4.00e+01 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   4, SO: firefly_dynamic & metr        , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  23, Trial:   5, SO: spiral_dynamic & all          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:  14, Trial:   5, SO: local_random_walk & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  24, Trial:   0, SO: genetic_mutation & metr       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  15, Trial:   3, SO: genetic_crossover & metr      , currPerf: 5.57e+02, candPerf: 5.57e+02 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  24, Trial:   1, SO: differential_mutation & metr  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   5, SO: differential_mutation & all   , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  15, Trial:   4, SO: genetic_crossover & metr      , currPerf: 5.57e+02, candPerf: 5.57e+02 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  23, Trial:   0, SO: local_random_walk & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   8, Step:  10, Trial:   2, SO: genetic_crossover & all       , currPerf: 5.34e-02, candPerf: 5.34e-02 which: entered    +
# ...
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  24, Trial:   5, SO: genetic_crossover & all       , currPerf: 2.02e+01, candPerf: 2.02e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  24, Trial:   6, SO: genetic_crossover & prob      , currPerf: 2.02e+01, candPerf: 2.02e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  24, Trial:   7, SO: spiral_dynamic & metr         , currPerf: 2.02e+01, candPerf: 2.02e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  24, Trial:   8, SO: genetic_crossover & prob      , currPerf: 2.02e+01, candPerf: 2.02e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  24, Trial:   9, SO: random_flight & gree          , currPerf: 2.02e+01, candPerf: 2.02e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  24, Trial:  10, SO: local_random_walk & all       , currPerf: 2.02e+01, candPerf: 2.02e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  24, Trial:  11, SO: central_force_dynamic & all   , currPerf: 2.02e+01, candPerf: 2.02e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  24, Trial:  12, SO: genetic_mutation & all        , currPerf: 2.02e+01, candPerf: 2.02e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  24, Trial:  13, SO: genetic_crossover & gree      , currPerf: 2.02e+01, candPerf: 2.02e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  24, Trial:  14, SO: genetic_crossover & prob      , currPerf: 2.02e+01, candPerf: 2.02e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  24, Trial:  15, SO: random_search & gree          , currPerf: 2.02e+01, candPerf: 1.33e+01, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:   0, SO: swarm_dynamic & prob          , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:   1, SO: genetic_crossover & all       , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:   2, SO: genetic_crossover & gree      , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:   3, SO: genetic_mutation & prob       , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:   4, SO: random_flight & metr          , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:   5, SO: differential_mutation & all   , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:   6, SO: genetic_crossover & metr      , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:   7, SO: genetic_crossover & all       , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:   8, SO: swarm_dynamic & all           , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:   9, SO: local_random_walk & gree      , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:  10, SO: random_flight & prob          , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:  11, SO: genetic_crossover & all       , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:  12, SO: genetic_crossover & prob      , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:  13, SO: gravitational_search & gree   , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:  14, SO: genetic_crossover & metr      , currPerf: 1.33e+01, candPerf: 1.33e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  25, Trial:  15, SO: genetic_crossover & all       , currPerf: 1.33e+01, candPerf: 7.29e+00, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  26, Trial:   0, SO: genetic_crossover & prob      , currPerf: 7.29e+00, candPerf: 7.29e+00, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  26, Trial:   1, SO: genetic_crossover & prob      , currPerf: 7.29e+00, candPerf: 7.29e+00, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  26, Trial:   2, SO: local_random_walk & all       , currPerf: 7.29e+00, candPerf: 7.29e+00, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  26, Trial:   3, SO: random_flight & gree          , currPerf: 7.29e+00, candPerf: 7.29e+00, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  26, Trial:   4, SO: random_search & prob          , currPerf: 7.29e+00, candPerf: 5.85e+00, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  27, Trial:   0, SO: spiral_dynamic & gree         , currPerf: 5.85e+00, candPerf: 5.85e+00, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  27, Trial:   1, SO: swarm_dynamic & gree          , currPerf: 5.85e+00, candPerf: 5.25e+00, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  28, Trial:   0, SO: firefly_dynamic & gree        , currPerf: 5.25e+00, candPerf: 5.25e+00, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  28, Trial:   1, SO: genetic_crossover & metr      , currPerf: 5.25e+00, candPerf: 3.21e+00, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  29, Trial:   0, SO: genetic_crossover & metr      , currPerf: 3.21e+00, candPerf: 3.16e+00, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  30, Trial:   0, SO: local_random_walk & metr      , currPerf: 3.16e+00, candPerf: 3.16e+00, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  30, Trial:   1, SO: swarm_dynamic & prob          , currPerf: 3.16e+00, candPerf: 3.16e+00, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  30, Trial:   2, SO: genetic_crossover & all       , currPerf: 3.16e+00, candPerf: 3.07e+00, csl: 205 +
#
# Best fitness: 3.0713707703072126,
# Best position: [ 1.10539579  0.76410791  0.53686937  0.28299461 -0.03697352 -0.20999194
#   0.62586495  0.642595   -0.20689294  0.06627014]
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   1, Trial:   0, SO: gravitational_search & metr   , currPerf: 1.55e+04, candPerf: 1.05e+04, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   2, Trial:   0, SO: genetic_crossover & all       , currPerf: 1.05e+04, candPerf: 2.71e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   3, Trial:   0, SO: differential_mutation & gree  , currPerf: 2.71e+03, candPerf: 2.71e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   3, Trial:   1, SO: differential_mutation & all   , currPerf: 2.71e+03, candPerf: 2.71e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   3, Trial:   2, SO: differential_mutation & gree  , currPerf: 2.71e+03, candPerf: 2.71e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   3, Trial:   3, SO: genetic_crossover & prob      , currPerf: 2.71e+03, candPerf: 2.71e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   3, Trial:   4, SO: genetic_crossover & all       , currPerf: 2.71e+03, candPerf: 1.61e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   4, Trial:   0, SO: random_search & metr          , currPerf: 1.61e+03, candPerf: 1.53e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   5, Trial:   0, SO: genetic_crossover & metr      , currPerf: 1.53e+03, candPerf: 1.44e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   6, Trial:   0, SO: genetic_crossover & gree      , currPerf: 1.44e+03, candPerf: 1.22e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   7, Trial:   0, SO: swarm_dynamic & prob          , currPerf: 1.22e+03, candPerf: 8.73e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   8, Trial:   0, SO: differential_mutation & metr  , currPerf: 8.73e+02, candPerf: 8.73e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   8, Trial:   1, SO: differential_mutation & gree  , currPerf: 8.73e+02, candPerf: 8.73e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   8, Trial:   2, SO: genetic_crossover & gree      , currPerf: 8.73e+02, candPerf: 7.74e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   9, Trial:   0, SO: genetic_crossover & prob      , currPerf: 7.74e+02, candPerf: 6.60e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  10, Trial:   0, SO: genetic_crossover & prob      , currPerf: 6.60e+02, candPerf: 5.54e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  11, Trial:   0, SO: genetic_crossover & metr      , currPerf: 5.54e+02, candPerf: 4.53e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  12, Trial:   0, SO: genetic_crossover & all       , currPerf: 4.53e+02, candPerf: 3.60e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  13, Trial:   0, SO: spiral_dynamic & gree         , currPerf: 3.60e+02, candPerf: 2.83e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  14, Trial:   0, SO: differential_mutation & all   , currPerf: 2.83e+02, candPerf: 2.83e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  14, Trial:   1, SO: differential_mutation & gree  , currPerf: 2.83e+02, candPerf: 2.79e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  15, Trial:   0, SO: genetic_crossover & prob      , currPerf: 2.79e+02, candPerf: 2.35e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  16, Trial:   0, SO: random_search & prob          , currPerf: 2.35e+02, candPerf: 2.35e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  16, Trial:   1, SO: genetic_crossover & prob      , currPerf: 2.35e+02, candPerf: 2.35e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  16, Trial:   2, SO: genetic_crossover & prob      , currPerf: 2.35e+02, candPerf: 2.05e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  17, Trial:   0, SO: random_flight & metr          , currPerf: 2.05e+02, candPerf: 1.45e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  18, Trial:   0, SO: firefly_dynamic & metr        , currPerf: 1.45e+02, candPerf: 1.45e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  18, Trial:   1, SO: swarm_dynamic & gree          , currPerf: 1.45e+02, candPerf: 1.45e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  18, Trial:   2, SO: genetic_crossover & metr      , currPerf: 1.45e+02, candPerf: 1.30e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  19, Trial:   0, SO: swarm_dynamic & prob          , currPerf: 1.30e+02, candPerf: 7.65e+01, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  20, Trial:   0, SO: differential_mutation & prob  , currPerf: 7.65e+01, candPerf: 6.93e+01, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:   0, SO: random_sample & all           , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:   1, SO: differential_mutation & all   , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:   2, SO: random_flight & all           , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:   3, SO: random_sample & metr          , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:   4, SO: firefly_dynamic & prob        , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:   5, SO: genetic_crossover & prob      , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:   6, SO: differential_mutation & prob  , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:   7, SO: genetic_crossover & metr      , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:   8, SO: genetic_crossover & prob      , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:   9, SO: genetic_crossover & metr      , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:  10, SO: genetic_crossover & prob      , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:  11, SO: swarm_dynamic & metr          , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:  12, SO: genetic_crossover & gree      , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:  13, SO: genetic_crossover & gree      , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:  14, SO: genetic_crossover & metr      , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:  15, SO: genetic_crossover & gree      , currPerf: 6.93e+01, candPerf: 6.93e+01, csl: 205
#
# Best fitness: 69.28716142407282,
# Best position: [ 0.01656198 -1.95635133 -5.30624692  1.3951438   3.22759945 -0.04309049
#  -3.58220618  0.12936604  0.43584087 -3.44945576]
# Sphere-10D-demo_default_nn_lstm_mem done!
#
# Preprocessing demo_default_nn_lstm_mem
# Step 2D, last=9: 100% 10/10 [00:00<00:00, 1902.78it/s]
# Sphere 2D, last=9: 100% 10/10 [00:00<00:00, 1704.38it/s]
# ZeroSum 2D, last=9: 100% 10/10 [00:00<00:00, 2591.96it/s]
# ZeroSum 10D, last=9: 100% 10/10 [00:00<00:00, 2377.18it/s]
# Sphere 10D, last=9: 100% 10/10 [00:00<00:00, 907.21it/s]
# Step 10D, last=9: 100% 10/10 [00:00<00:00, 1408.15it/s]
#
# Changing folder name of raw results...
#
# Experiment(s) finished!

# %% [markdown]
# ### Execute a batch of experiments

# %%
# !python experiment.py  -b exconf/lstm_demo.conf
# Out:
# Streaming output truncated to the last 5000 lines.
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   2, Trial:   0, SO: differential_mutation & gree  , currPerf: 2.09e+02, candPerf: 5.23e+01 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  29, Trial:   0, SO: local_random_walk & metr      , currPerf: 4.00e+01, candPerf: 4.00e+01 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  29, Trial:   1, SO: differential_mutation & all   , currPerf: 4.00e+01, candPerf: 4.00e+01 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   6, Trial:   3, SO: random_sample & metr          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  21, Trial:   1, SO: firefly_dynamic & gree        , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   1, SO: random_search & prob          , currPerf: 1.68e+03, candPerf: 1.47e+03 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  11, Trial:   0, SO: swarm_dynamic & all           , currPerf: 1.47e+03, candPerf: 1.47e+03 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  21, Trial:   2, SO: genetic_crossover & prob      , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:   9, Trial:   1, SO: differential_mutation & metr  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   3, Trial:   0, SO: central_force_dynamic & metr  , currPerf: 5.23e+01, candPerf: 5.23e+01 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   4, Trial:   0, SO: differential_mutation & gree  , currPerf: 5.23e+01, candPerf: 5.23e+01 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  29, Trial:   2, SO: differential_mutation & all   , currPerf: 4.00e+01, candPerf: 4.00e+01 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  21, Trial:   3, SO: spiral_dynamic & prob         , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  29, Trial:   3, SO: genetic_crossover & metr      , currPerf: 4.00e+01, candPerf: 4.00e+01 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   6, Trial:   4, SO: swarm_dynamic & prob          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   7, Trial:   0, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   5, Trial:   0, SO: genetic_crossover & gree      , currPerf: 5.23e+01, candPerf: 1.43e+01 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   6, Trial:   0, SO: swarm_dynamic & gree          , currPerf: 1.43e+01, candPerf: 8.87e+00 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  11, Trial:   1, SO: random_search & all           , currPerf: 1.47e+03, candPerf: 1.47e+03 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  21, Trial:   4, SO: genetic_crossover & gree      , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  11, Trial:   2, SO: genetic_crossover & prob      , currPerf: 1.47e+03, candPerf: 1.36e+03 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   7, Trial:   1, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  21, Trial:   5, SO: random_flight & metr          , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  29, Trial:   4, SO: differential_mutation & all   , currPerf: 4.00e+01, candPerf: 4.00e+01 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  29, Trial:   5, SO: genetic_crossover & metr      , currPerf: 4.00e+01, candPerf: 4.00e+01 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   7, Trial:   0, SO: genetic_crossover & metr      , currPerf: 8.87e+00, candPerf: 4.05e-02 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  12, Trial:   0, SO: genetic_crossover & all       , currPerf: 1.36e+03, candPerf: 1.36e+03 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:   9, Trial:   2, SO: firefly_dynamic & prob        , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  21, Trial:   6, SO: genetic_crossover & gree      , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  10, Trial:   0, SO: genetic_mutation & prob       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   7, Trial:   2, SO: differential_mutation & prob  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   7, Trial:   3, SO: swarm_dynamic & prob          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:   0, SO: random_search & prob          , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   0, SO: differential_mutation & metr  , currPerf: 4.05e-02, candPerf: 4.05e-02 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   1, SO: differential_mutation & metr  , currPerf: 4.05e-02, candPerf: 4.05e-02 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  10, Trial:   1, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  22, Trial:   1, SO: random_search & all           , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  11, Trial:   0, SO: genetic_mutation & gree       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   2, SO: genetic_crossover & metr      , currPerf: 4.05e-02, candPerf: 4.05e-02 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  30, Trial:   0, SO: firefly_dynamic & metr        , currPerf: 4.00e+01, candPerf: 4.00e+01 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  12, Trial:   1, SO: central_force_dynamic & prob  , currPerf: 1.36e+03, candPerf: 1.36e+03 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  12, Trial:   0, SO: firefly_dynamic & prob        , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  23, Trial:   0, SO: random_flight & metr          , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  30, Trial:   1, SO: swarm_dynamic & prob          , currPerf: 4.00e+01, candPerf: 4.00e+01 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   7, Trial:   4, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  30, Trial:   2, SO: genetic_crossover & metr      , currPerf: 4.00e+01, candPerf: 4.00e+01 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   8, Trial:   0, SO: spiral_dynamic & prob         , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  12, Trial:   1, SO: local_random_walk & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   3, SO: swarm_dynamic & gree          , currPerf: 4.05e-02, candPerf: 4.05e-02 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   8, Step:  30, Trial:   3, SO: genetic_crossover & prob      , currPerf: 4.00e+01, candPerf: 4.00e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  13, Trial:   0, SO: random_search & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
#
# Best fitness: 40.0,
# Best position: [ 5.0027986  -0.71653362 -6.23911352 -0.0607408  -2.55285157  2.11772926
#  10.93443239  2.62292736  5.56666882  8.28541799]
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  12, Trial:   2, SO: firefly_dynamic & prob        , currPerf: 1.36e+03, candPerf: 1.36e+03 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  24, Trial:   0, SO: genetic_crossover & all       , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   1, Trial:   0, SO: genetic_crossover & gree      , currPerf: 2.93e+02, candPerf: 2.93e+02 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  14, Trial:   0, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   4, SO: genetic_crossover & prob      , currPerf: 4.05e-02, candPerf: 4.05e-02 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   2, Trial:   0, SO: swarm_dynamic & prob          , currPerf: 2.93e+02, candPerf: 2.64e+02 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  14, Trial:   1, SO: genetic_mutation & gree       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   5, SO: random_search & metr          , currPerf: 4.05e-02, candPerf: 4.05e-02 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  15, Trial:   0, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  13, Trial:   0, SO: genetic_crossover & all       , currPerf: 1.36e+03, candPerf: 1.36e+03 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  24, Trial:   1, SO: genetic_crossover & all       , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   8, Trial:   1, SO: firefly_dynamic & metr        , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  25, Trial:   0, SO: genetic_mutation & all        , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   3, Trial:   0, SO: swarm_dynamic & metr          , currPerf: 2.64e+02, candPerf: 1.98e+02 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   6, SO: differential_mutation & gree  , currPerf: 4.05e-02, candPerf: 4.05e-02 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   8, Trial:   2, SO: swarm_dynamic & prob          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  15, Trial:   1, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  25, Trial:   1, SO: genetic_crossover & gree      , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   7, SO: genetic_crossover & gree      , currPerf: 4.05e-02, candPerf: 4.05e-02 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   4, Trial:   0, SO: genetic_crossover & gree      , currPerf: 1.98e+02, candPerf: 1.98e+02 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  13, Trial:   1, SO: firefly_dynamic & prob        , currPerf: 1.36e+03, candPerf: 1.36e+03 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  25, Trial:   2, SO: differential_mutation & prob  , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   9, Trial:   0, SO: spiral_dynamic & metr         , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   9, Trial:   1, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   8, SO: genetic_crossover & gree      , currPerf: 4.05e-02, candPerf: 4.05e-02 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   0, SO: genetic_crossover & metr      , currPerf: 1.36e+03, candPerf: 1.29e+03 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  15, Trial:   2, SO: random_flight & prob          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   4, Trial:   1, SO: differential_mutation & prob  , currPerf: 1.98e+02, candPerf: 1.98e+02 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  25, Trial:   3, SO: random_sample & metr          , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  16, Trial:   0, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   9, SO: genetic_crossover & prob      , currPerf: 4.05e-02, candPerf: 4.05e-02 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   5, Trial:   0, SO: genetic_crossover & prob      , currPerf: 1.98e+02, candPerf: 1.56e+02 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  16, Trial:   1, SO: differential_mutation & all   , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  16, Trial:   2, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  16, Trial:   3, SO: random_sample & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   6, Trial:   0, SO: firefly_dynamic & prob        , currPerf: 1.56e+02, candPerf: 1.56e+02 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  17, Trial:   0, SO: swarm_dynamic & metr          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   6, Trial:   1, SO: genetic_crossover & all       , currPerf: 1.56e+02, candPerf: 1.09e+02 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  25, Trial:   4, SO: swarm_dynamic & prob          , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  17, Trial:   1, SO: random_search & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   9, Trial:   2, SO: gravitational_search & all    , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   7, Trial:   0, SO: genetic_crossover & metr      , currPerf: 1.09e+02, candPerf: 8.10e+01 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  15, Trial:   0, SO: differential_mutation & prob  , currPerf: 1.29e+03, candPerf: 1.29e+03 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  17, Trial:   2, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  25, Trial:   5, SO: genetic_crossover & prob      , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   0, SO: genetic_crossover & prob      , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   9, Trial:   3, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   1, SO: genetic_crossover & prob      , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  16, Trial:   0, SO: random_search & prob          , currPerf: 1.29e+03, candPerf: 1.25e+03 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:  10, SO: genetic_crossover & prob      , currPerf: 4.05e-02, candPerf: 4.05e-02 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  17, Trial:   0, SO: genetic_crossover & gree      , currPerf: 1.25e+03, candPerf: 1.25e+03 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:  11, SO: genetic_crossover & all       , currPerf: 4.05e-02, candPerf: 3.68e-02 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  25, Trial:   6, SO: genetic_crossover & prob      , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  17, Trial:   3, SO: firefly_dynamic & all         , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  25, Trial:   7, SO: genetic_crossover & prob      , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  17, Trial:   4, SO: random_search & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   9, Trial:   4, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   9, Trial:   5, SO: random_search & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   2, SO: differential_mutation & all   , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   3, SO: differential_mutation & all   , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  17, Trial:   1, SO: genetic_crossover & gree      , currPerf: 1.25e+03, candPerf: 1.25e+03 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   8, Trial:   4, SO: differential_mutation & metr  , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  17, Trial:   2, SO: genetic_crossover & all       , currPerf: 1.25e+03, candPerf: 1.25e+03 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   9, Trial:   0, SO: genetic_crossover & metr      , currPerf: 3.68e-02, candPerf: 3.68e-02 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  17, Trial:   5, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   9, Trial:   1, SO: local_random_walk & gree      , currPerf: 3.68e-02, candPerf: 3.68e-02 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  26, Trial:   0, SO: genetic_mutation & gree       , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:   9, Trial:   6, SO: differential_mutation & all   , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  17, Trial:   6, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   9, Trial:   0, SO: genetic_mutation & prob       , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  17, Trial:   3, SO: genetic_mutation & all        , currPerf: 1.25e+03, candPerf: 1.25e+03 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  18, Trial:   0, SO: random_search & gree          , currPerf: 1.25e+03, candPerf: 1.16e+03 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:   9, Trial:   2, SO: genetic_crossover & all       , currPerf: 3.68e-02, candPerf: 3.26e-02 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   9, Trial:   1, SO: genetic_mutation & prob       , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  10, Trial:   0, SO: gravitational_search & metr   , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  17, Trial:   7, SO: swarm_dynamic & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  10, Trial:   1, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   0, SO: genetic_mutation & all        , currPerf: 3.26e-02, candPerf: 3.26e-02 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  19, Trial:   0, SO: random_search & all           , currPerf: 1.16e+03, candPerf: 1.14e+03 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  18, Trial:   0, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  20, Trial:   0, SO: genetic_crossover & gree      , currPerf: 1.14e+03, candPerf: 1.14e+03 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  26, Trial:   1, SO: central_force_dynamic & gree  , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  20, Trial:   1, SO: random_search & gree          , currPerf: 1.14e+03, candPerf: 1.14e+03 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   1, SO: genetic_crossover & metr      , currPerf: 3.26e-02, candPerf: 3.26e-02 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   0, SO: genetic_crossover & all       , currPerf: 1.14e+03, candPerf: 1.14e+03 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  18, Trial:   1, SO: swarm_dynamic & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  26, Trial:   2, SO: differential_mutation & all   , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  10, Trial:   2, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  19, Trial:   0, SO: differential_mutation & prob  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  10, Trial:   3, SO: swarm_dynamic & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  20, Trial:   0, SO: random_flight & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  26, Trial:   3, SO: genetic_crossover & gree      , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   2, SO: genetic_crossover & prob      , currPerf: 3.26e-02, candPerf: 3.26e-02 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  26, Trial:   4, SO: genetic_crossover & gree      , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   1, SO: genetic_crossover & all       , currPerf: 1.14e+03, candPerf: 1.14e+03 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  21, Trial:   0, SO: random_search & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   2, SO: local_random_walk & prob      , currPerf: 1.14e+03, candPerf: 7.47e+02 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:   9, Trial:   2, SO: firefly_dynamic & gree        , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  22, Trial:   0, SO: genetic_crossover & metr      , currPerf: 7.47e+02, candPerf: 7.47e+02 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   3, SO: genetic_mutation & prob       , currPerf: 3.26e-02, candPerf: 3.26e-02 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  11, Trial:   0, SO: random_sample & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  11, Trial:   1, SO: differential_mutation & all   , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   4, SO: genetic_crossover & metr      , currPerf: 3.26e-02, candPerf: 3.26e-02 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   0, SO: genetic_crossover & prob      , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   1, SO: genetic_crossover & prob      , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  21, Trial:   1, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  22, Trial:   1, SO: genetic_crossover & prob      , currPerf: 7.47e+02, candPerf: 7.47e+02 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  11, Trial:   2, SO: random_flight & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  12, Trial:   0, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   5, SO: swarm_dynamic & gree          , currPerf: 3.26e-02, candPerf: 2.24e-02 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  22, Trial:   2, SO: random_flight & gree          , currPerf: 7.47e+02, candPerf: 7.47e+02 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  26, Trial:   5, SO: gravitational_search & gree   , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   2, SO: differential_mutation & metr  , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  12, Trial:   1, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  11, Trial:   0, SO: genetic_crossover & gree      , currPerf: 2.24e-02, candPerf: 2.14e-02 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  26, Trial:   6, SO: random_search & gree          , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   3, SO: genetic_crossover & prob      , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  23, Trial:   0, SO: genetic_crossover & all       , currPerf: 7.47e+02, candPerf: 7.47e+02 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  21, Trial:   2, SO: firefly_dynamic & gree        , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  23, Trial:   1, SO: genetic_crossover & metr      , currPerf: 7.47e+02, candPerf: 7.34e+02 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  12, Trial:   0, SO: genetic_mutation & all        , currPerf: 2.14e-02, candPerf: 2.14e-02 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  21, Trial:   3, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   4, SO: genetic_crossover & metr      , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  27, Trial:   0, SO: differential_mutation & gree  , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   5, SO: local_random_walk & all       , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  28, Trial:   0, SO: local_random_walk & all       , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  13, Trial:   0, SO: random_search & all           , currPerf: 2.14e-02, candPerf: 1.65e-02 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  21, Trial:   4, SO: random_flight & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  24, Trial:   0, SO: differential_mutation & metr  , currPerf: 7.34e+02, candPerf: 3.19e+02 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  25, Trial:   0, SO: genetic_crossover & gree      , currPerf: 3.19e+02, candPerf: 3.19e+02 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   6, SO: differential_mutation & gree  , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  12, Trial:   2, SO: central_force_dynamic & all   , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  28, Trial:   1, SO: random_flight & all           , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   7, SO: genetic_crossover & gree      , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   0, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   0, SO: gravitational_search & all    , currPerf: 1.65e-02, candPerf: 1.65e-02 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  12, Trial:   3, SO: differential_mutation & prob  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   8, SO: genetic_crossover & gree      , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  12, Trial:   4, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   1, SO: genetic_crossover & all       , currPerf: 1.65e-02, candPerf: 8.08e-03 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   1, SO: random_flight & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  25, Trial:   1, SO: genetic_crossover & all       , currPerf: 3.19e+02, candPerf: 3.19e+02 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   2, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  25, Trial:   2, SO: genetic_mutation & gree       , currPerf: 3.19e+02, candPerf: 3.19e+02 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:   9, SO: genetic_crossover & metr      , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  29, Trial:   0, SO: firefly_dynamic & metr        , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  13, Trial:   0, SO: genetic_mutation & metr       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  25, Trial:   3, SO: genetic_crossover & metr      , currPerf: 3.19e+02, candPerf: 3.19e+02 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  13, Trial:   1, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  15, Trial:   0, SO: genetic_crossover & all       , currPerf: 8.08e-03, candPerf: 2.44e-03 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  16, Trial:   0, SO: differential_mutation & gree  , currPerf: 2.44e-03, candPerf: 2.18e-03 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   3, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  29, Trial:   1, SO: genetic_mutation & metr       , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   4, SO: random_search & gree          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  17, Trial:   0, SO: genetic_crossover & gree      , currPerf: 2.18e-03, candPerf: 2.18e-03 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:  10, SO: genetic_mutation & all        , currPerf: 8.10e+01, candPerf: 8.10e+01 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  10, Trial:  11, SO: genetic_crossover & all       , currPerf: 8.10e+01, candPerf: 6.80e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   5, SO: differential_mutation & prob  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  18, Trial:   0, SO: genetic_crossover & gree      , currPerf: 2.18e-03, candPerf: 2.73e-04 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  11, Trial:   0, SO: random_search & prob          , currPerf: 6.80e+01, candPerf: 6.40e+01 which: entered    +
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   6, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  12, Trial:   0, SO: local_random_walk & prob      , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  19, Trial:   0, SO: local_random_walk & metr      , currPerf: 2.73e-04, candPerf: 2.73e-04 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   7, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  13, Trial:   2, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  25, Trial:   4, SO: firefly_dynamic & metr        , currPerf: 3.19e+02, candPerf: 3.19e+02 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  19, Trial:   1, SO: random_sample & metr          , currPerf: 2.73e-04, candPerf: 2.73e-04 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  25, Trial:   5, SO: genetic_crossover & gree      , currPerf: 3.19e+02, candPerf: 3.19e+02 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  29, Trial:   2, SO: central_force_dynamic & all   , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  12, Trial:   1, SO: genetic_mutation & all        , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  13, Trial:   0, SO: random_flight & metr          , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  25, Trial:   6, SO: genetic_crossover & gree      , currPerf: 3.19e+02, candPerf: 3.19e+02 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  29, Trial:   3, SO: local_random_walk & all       , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  25, Trial:   7, SO: local_random_walk & prob      , currPerf: 3.19e+02, candPerf: 3.15e+02 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  13, Trial:   3, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  29, Trial:   4, SO: random_search & all           , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   0, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  20, Trial:   0, SO: genetic_crossover & metr      , currPerf: 2.73e-04, candPerf: 1.73e-04 which: entered    +
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   0, SO: genetic_crossover & all       , currPerf: 1.73e-04, candPerf: 1.73e-04 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  29, Trial:   5, SO: genetic_crossover & all       , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  13, Trial:   1, SO: differential_mutation & gree  , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   0, SO: differential_mutation & prob  , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  29, Trial:   6, SO: differential_mutation & metr  , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   8, SO: firefly_dynamic & prob        , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:   9, SO: differential_mutation & metr  , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  26, Trial:   0, SO: central_force_dynamic & all   , currPerf: 3.15e+02, candPerf: 3.15e+02 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   1, SO: swarm_dynamic & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  29, Trial:   7, SO: genetic_crossover & gree      , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  26, Trial:   1, SO: genetic_crossover & gree      , currPerf: 3.15e+02, candPerf: 3.15e+02 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   2, SO: random_flight & prob          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  26, Trial:   2, SO: genetic_crossover & all       , currPerf: 3.15e+02, candPerf: 3.15e+02 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   1, SO: random_search & prob          , currPerf: 1.73e-04, candPerf: 1.73e-04 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  29, Trial:   8, SO: genetic_crossover & gree      , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   1, SO: random_flight & prob          , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   2, SO: genetic_crossover & all       , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  26, Trial:   3, SO: genetic_crossover & all       , currPerf: 3.15e+02, candPerf: 3.15e+02 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  29, Trial:   9, SO: genetic_crossover & all       , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:  10, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  29, Trial:  10, SO: genetic_crossover & all       , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  26, Trial:   4, SO: genetic_crossover & prob      , currPerf: 3.15e+02, candPerf: 2.22e+02 which: entered    +
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  30, Trial:   0, SO: genetic_crossover & gree      , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   3, SO: genetic_crossover & gree      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  27, Trial:   0, SO: genetic_crossover & all       , currPerf: 2.22e+02, candPerf: 2.14e+02 which: entered    +
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   4, SO: random_sample & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  22, Trial:  11, SO: random_search & all           , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   3, SO: genetic_mutation & metr       , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   2, SO: firefly_dynamic & metr        , currPerf: 1.73e-04, candPerf: 1.73e-04 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   5, SO: swarm_dynamic & prob          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  30, Trial:   1, SO: genetic_crossover & all       , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   3, SO: genetic_crossover & prob      , currPerf: 1.73e-04, candPerf: 1.73e-04 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  23, Trial:   0, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  28, Trial:   0, SO: swarm_dynamic & all           , currPerf: 2.14e+02, candPerf: 1.98e+02 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  29, Trial:   0, SO: genetic_crossover & prob      , currPerf: 1.98e+02, candPerf: 1.98e+02 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  24, Trial:   0, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   4, SO: genetic_crossover & metr      , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   4, SO: swarm_dynamic & gree          , currPerf: 1.73e-04, candPerf: 1.73e-04 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   5, SO: random_flight & all           , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   6, SO: genetic_crossover & metr      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   6, Step:  30, Trial:   2, SO: genetic_mutation & prob       , currPerf: 4.40e+00, candPerf: 4.40e+00 which: entered    +
#
# Best fitness: 4.401796726572685,
# Best position: [-9.78086083  0.44934451 -5.03193175 -4.01157124 -0.13638141  0.25711533
#   0.516982    6.6866533  10.          1.04949287]
# ZeroSum-2D-demo_default_nn_lstm_mem :: Rep:   6, Step:  14, Trial:   7, SO: random_flight & metr          , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  25, Trial:   0, SO: genetic_mutation & prob       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   5, SO: genetic_crossover & all       , currPerf: 1.73e-04, candPerf: 1.73e-04 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   6, SO: random_flight & prob          , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   7, SO: genetic_crossover & gree      , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  29, Trial:   1, SO: genetic_mutation & all        , currPerf: 1.98e+02, candPerf: 1.98e+02 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  21, Trial:   6, SO: differential_mutation & all   , currPerf: 1.73e-04, candPerf: 4.20e-05 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  29, Trial:   2, SO: local_random_walk & prob      , currPerf: 1.98e+02, candPerf: 1.98e+02 which: entered    +
# Sphere-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  30, Trial:   0, SO: random_flight & gree          , currPerf: 1.98e+02, candPerf: 1.98e+02 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  25, Trial:   1, SO: genetic_crossover & prob      , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   1, Trial:   0, SO: random_search & all           , currPerf: 7.62e+01, candPerf: 7.62e+01 which: entered
# Sphere-2D-demo_default_nn_lstm_mem :: Rep:   9, Step:  22, Trial:   0, SO: differential_mutation & prob  , currPerf: 4.20e-05, candPerf: 4.20e-05 which: entered
# ZeroSum-10D-demo_default_nn_lstm_mem :: Rep:   7, Step:   1, Trial:   1, SO: local_random_walk & gree      , currPerf: 7.62e+01, candPerf: 3.59e+01 which: entered    +
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   8, SO: random_sample & gree          , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered
# Step-2D-demo_default_nn_lstm_mem :: Rep:   7, Step:  25, Trial:   2, SO: genetic_crossover & all       , currPerf: 0.00e+00, candPerf: 0.00e+00 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:   9, SO: random_flight & prob          , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered
# Step-10D-demo_default_nn_lstm_mem :: Rep:   9, Step:  14, Trial:  10, SO: differential_mutation & gree  , currPerf: 6.40e+01, candPerf: 6.40e+01 which: entered
# ...
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  30, Trial:   2, SO: random_flight & prob          , currPerf: 4.89e+01, candPerf: 4.89e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  30, Trial:   3, SO: genetic_crossover & gree      , currPerf: 4.89e+01, candPerf: 4.89e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  30, Trial:   4, SO: swarm_dynamic & metr          , currPerf: 4.89e+01, candPerf: 4.89e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  30, Trial:   5, SO: random_flight & gree          , currPerf: 4.89e+01, candPerf: 4.89e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  30, Trial:   6, SO: differential_mutation & all   , currPerf: 4.89e+01, candPerf: 4.89e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  30, Trial:   7, SO: genetic_crossover & gree      , currPerf: 4.89e+01, candPerf: 4.89e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  30, Trial:   8, SO: firefly_dynamic & gree        , currPerf: 4.89e+01, candPerf: 4.89e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  30, Trial:   9, SO: genetic_mutation & metr       , currPerf: 4.89e+01, candPerf: 4.89e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  30, Trial:  10, SO: genetic_crossover & metr      , currPerf: 4.89e+01, candPerf: 4.89e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  30, Trial:  11, SO: firefly_dynamic & metr        , currPerf: 4.89e+01, candPerf: 4.89e+01, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:   9, Step:  30, Trial:  12, SO: genetic_crossover & prob      , currPerf: 4.89e+01, candPerf: 2.36e+01, csl: 205 +
#
# Best fitness: 23.554794107061998,
# Best position: [ 0.33185887 -3.2789163   1.29015009  0.88550049 -1.50012392  0.08976416
#   1.40745816 -2.23366443 -0.7472491  -0.67658513]
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   1, Trial:   0, SO: genetic_crossover & prob      , currPerf: 1.78e+04, candPerf: 5.90e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   2, Trial:   0, SO: genetic_crossover & gree      , currPerf: 5.90e+03, candPerf: 5.90e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   2, Trial:   1, SO: random_search & all           , currPerf: 5.90e+03, candPerf: 5.87e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   3, Trial:   0, SO: spiral_dynamic & prob         , currPerf: 5.87e+03, candPerf: 5.87e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   3, Trial:   1, SO: genetic_crossover & metr      , currPerf: 5.87e+03, candPerf: 5.87e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   3, Trial:   2, SO: genetic_crossover & gree      , currPerf: 5.87e+03, candPerf: 5.87e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   3, Trial:   3, SO: swarm_dynamic & all           , currPerf: 5.87e+03, candPerf: 5.28e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   4, Trial:   0, SO: genetic_mutation & all        , currPerf: 5.28e+03, candPerf: 5.28e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   4, Trial:   1, SO: spiral_dynamic & all          , currPerf: 5.28e+03, candPerf: 5.28e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   4, Trial:   2, SO: genetic_crossover & all       , currPerf: 5.28e+03, candPerf: 4.94e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   5, Trial:   0, SO: genetic_crossover & prob      , currPerf: 4.94e+03, candPerf: 4.94e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   5, Trial:   1, SO: genetic_crossover & all       , currPerf: 4.94e+03, candPerf: 4.94e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   5, Trial:   2, SO: differential_mutation & prob  , currPerf: 4.94e+03, candPerf: 4.94e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   5, Trial:   3, SO: genetic_crossover & metr      , currPerf: 4.94e+03, candPerf: 4.94e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   5, Trial:   4, SO: genetic_crossover & prob      , currPerf: 4.94e+03, candPerf: 3.07e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   6, Trial:   0, SO: random_sample & metr          , currPerf: 3.07e+03, candPerf: 3.07e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   6, Trial:   1, SO: local_random_walk & prob      , currPerf: 3.07e+03, candPerf: 2.89e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   7, Trial:   0, SO: genetic_crossover & metr      , currPerf: 2.89e+03, candPerf: 2.89e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   7, Trial:   1, SO: gravitational_search & all    , currPerf: 2.89e+03, candPerf: 2.89e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   7, Trial:   2, SO: genetic_crossover & all       , currPerf: 2.89e+03, candPerf: 2.17e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   8, Trial:   0, SO: genetic_crossover & prob      , currPerf: 2.17e+03, candPerf: 2.17e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   8, Trial:   1, SO: differential_mutation & metr  , currPerf: 2.17e+03, candPerf: 2.17e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   8, Trial:   2, SO: differential_mutation & prob  , currPerf: 2.17e+03, candPerf: 1.73e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:   9, Trial:   0, SO: differential_mutation & prob  , currPerf: 1.73e+03, candPerf: 1.73e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  10, Trial:   0, SO: swarm_dynamic & prob          , currPerf: 1.73e+03, candPerf: 1.73e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  10, Trial:   1, SO: central_force_dynamic & all   , currPerf: 1.73e+03, candPerf: 1.73e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  10, Trial:   2, SO: swarm_dynamic & metr          , currPerf: 1.73e+03, candPerf: 1.73e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  10, Trial:   3, SO: differential_mutation & prob  , currPerf: 1.73e+03, candPerf: 1.71e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  11, Trial:   0, SO: random_flight & prob          , currPerf: 1.71e+03, candPerf: 1.71e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  11, Trial:   1, SO: gravitational_search & gree   , currPerf: 1.71e+03, candPerf: 1.71e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  11, Trial:   2, SO: local_random_walk & gree      , currPerf: 1.71e+03, candPerf: 1.71e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  11, Trial:   3, SO: differential_mutation & all   , currPerf: 1.71e+03, candPerf: 1.71e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  11, Trial:   4, SO: genetic_crossover & all       , currPerf: 1.71e+03, candPerf: 1.71e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  11, Trial:   5, SO: genetic_crossover & gree      , currPerf: 1.71e+03, candPerf: 1.71e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  11, Trial:   6, SO: genetic_crossover & metr      , currPerf: 1.71e+03, candPerf: 1.40e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  12, Trial:   0, SO: gravitational_search & gree   , currPerf: 1.40e+03, candPerf: 1.40e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  12, Trial:   1, SO: swarm_dynamic & gree          , currPerf: 1.40e+03, candPerf: 1.40e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  12, Trial:   2, SO: genetic_crossover & gree      , currPerf: 1.40e+03, candPerf: 1.40e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  12, Trial:   3, SO: genetic_crossover & gree      , currPerf: 1.40e+03, candPerf: 1.34e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  13, Trial:   0, SO: genetic_mutation & prob       , currPerf: 1.34e+03, candPerf: 1.34e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  13, Trial:   1, SO: random_search & all           , currPerf: 1.34e+03, candPerf: 1.28e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  14, Trial:   0, SO: swarm_dynamic & metr          , currPerf: 1.28e+03, candPerf: 1.28e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  14, Trial:   1, SO: random_flight & prob          , currPerf: 1.28e+03, candPerf: 1.18e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  15, Trial:   0, SO: random_search & gree          , currPerf: 1.18e+03, candPerf: 1.18e+03, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  15, Trial:   1, SO: swarm_dynamic & all           , currPerf: 1.18e+03, candPerf: 1.11e+03, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  16, Trial:   0, SO: genetic_crossover & metr      , currPerf: 1.11e+03, candPerf: 9.50e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  17, Trial:   0, SO: local_random_walk & metr      , currPerf: 9.50e+02, candPerf: 9.50e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  17, Trial:   1, SO: differential_mutation & metr  , currPerf: 9.50e+02, candPerf: 9.19e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  18, Trial:   0, SO: firefly_dynamic & gree        , currPerf: 9.19e+02, candPerf: 9.19e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  18, Trial:   1, SO: genetic_mutation & all        , currPerf: 9.19e+02, candPerf: 9.19e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  18, Trial:   2, SO: genetic_mutation & gree       , currPerf: 9.19e+02, candPerf: 9.19e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  18, Trial:   3, SO: genetic_crossover & gree      , currPerf: 9.19e+02, candPerf: 9.19e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  18, Trial:   4, SO: local_random_walk & prob      , currPerf: 9.19e+02, candPerf: 9.19e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  18, Trial:   5, SO: genetic_crossover & all       , currPerf: 9.19e+02, candPerf: 9.19e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  18, Trial:   6, SO: genetic_crossover & gree      , currPerf: 9.19e+02, candPerf: 7.72e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  19, Trial:   0, SO: spiral_dynamic & prob         , currPerf: 7.72e+02, candPerf: 7.72e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  19, Trial:   1, SO: genetic_crossover & gree      , currPerf: 7.72e+02, candPerf: 6.44e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  20, Trial:   0, SO: swarm_dynamic & prob          , currPerf: 6.44e+02, candPerf: 6.44e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  20, Trial:   1, SO: genetic_crossover & gree      , currPerf: 6.44e+02, candPerf: 5.40e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  21, Trial:   0, SO: random_flight & prob          , currPerf: 5.40e+02, candPerf: 4.60e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  22, Trial:   0, SO: genetic_crossover & metr      , currPerf: 4.60e+02, candPerf: 3.21e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  23, Trial:   0, SO: genetic_crossover & prob      , currPerf: 3.21e+02, candPerf: 3.20e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  24, Trial:   0, SO: genetic_crossover & all       , currPerf: 3.20e+02, candPerf: 2.53e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  25, Trial:   0, SO: genetic_crossover & metr      , currPerf: 2.53e+02, candPerf: 2.53e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  25, Trial:   1, SO: local_random_walk & gree      , currPerf: 2.53e+02, candPerf: 2.46e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  26, Trial:   0, SO: swarm_dynamic & prob          , currPerf: 2.46e+02, candPerf: 1.98e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  27, Trial:   0, SO: differential_mutation & metr  , currPerf: 1.98e+02, candPerf: 1.98e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  27, Trial:   1, SO: differential_mutation & metr  , currPerf: 1.98e+02, candPerf: 1.98e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  27, Trial:   2, SO: genetic_mutation & prob       , currPerf: 1.98e+02, candPerf: 1.98e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  27, Trial:   3, SO: genetic_mutation & all        , currPerf: 1.98e+02, candPerf: 1.98e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  27, Trial:   4, SO: genetic_crossover & gree      , currPerf: 1.98e+02, candPerf: 1.81e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  28, Trial:   0, SO: genetic_crossover & prob      , currPerf: 1.81e+02, candPerf: 1.59e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  29, Trial:   0, SO: genetic_crossover & metr      , currPerf: 1.59e+02, candPerf: 1.59e+02, csl: 205
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  29, Trial:   1, SO: genetic_crossover & gree      , currPerf: 1.59e+02, candPerf: 1.44e+02, csl: 205 +
# Sphere-10D-demo_default_nn_lstm_mem :: Neural Network, Rep:  10, Step:  30, Trial:   0, SO: differential_mutation & gree  , currPerf: 1.44e+02, candPerf: 1.30e+02, csl: 205 +
#
# Best fitness: 129.58007736760865,
# Best position: [ 1.91012425 -3.41429793 -5.41002828  3.59021615 -2.06712447  5.19967832
#   5.40249907 -0.10983311 -2.22888974 -2.57669308]
# Sphere-10D-demo_default_nn_lstm_mem done!
#
# Preprocessing demo_default_nn_lstm_mem - (2/2)
# ==================================================
# Step 2D, last=9: 100% 10/10 [00:00<00:00, 2114.81it/s]
# Sphere 2D, last=9: 100% 10/10 [00:00<00:00, 1061.50it/s]
# ZeroSum 2D, last=9: 100% 10/10 [00:00<00:00, 3139.68it/s]
# ZeroSum 10D, last=9: 100% 10/10 [00:00<00:00, 2379.07it/s]
# Sphere 10D, last=9: 100% 10/10 [00:00<00:00, 1009.99it/s]
# Step 10D, last=9: 100% 10/10 [00:00<00:00, 1321.46it/s]
#
# Changing folder name of raw results...
#
# Experiment(s) finished!

# %% [markdown]
# ### Review results

# %% [markdown]
# The results are processed and stored in `./exp_output/`. To visualize these results, you should check the [main notebook of the repository](https://github.com/jose-tapia/nn-hh-umhs-cec22/blob/bc9c0806c5e81f13027a969bee6debfb1e6d207d/processing_results_nnhh.ipynb) and add the data of your experiment in the third cell of the notebook.
#
# For example, you can modify the list by:
# ```
# data_files = dict({
#   'lstm_demo_mem': {
#     'filename': 'demo_default_nn_lstm_mem', # This name must match the name of the file
#     'ID': 'LSTM\_mem\_demo', # This ID will show up in the figures, use \_ to add underscores
#   },
# })
# ```
#
#
# Neural network models can be found in `ml_models` with their training information.
#
# Raw results can be found in `./data_files/raw-...{name of your experiment}`.
